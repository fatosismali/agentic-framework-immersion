# %% [markdown]
# ## 🔐 Prerequisites
#
# Before running the first cell, make sure you're authenticated with Azure CLI:
#
# ```bash
# az login
# ```
#
# # 💬 Chat Middleware
#
# ## Industry Use Case: Customer Service Message Filtering
#
# This notebook demonstrates **chat middleware** for intercepting and modifying messages.
#
# | Feature | FSI Application |
# |---------|-----------------|
# | **Message Observation** | Audit logging for compliance |
# | **Message Modification** | PII redaction |
# | **Response Override** | Block sensitive queries |

# %%
import os
from dotenv import load_dotenv

load_dotenv('../../.env', override=True)

PROJECT_ENDPOINT = os.getenv("AI_FOUNDRY_PROJECT_ENDPOINT")

print(f"✅ Environment loaded")
# Out:
# ✅ Environment loaded

# %%
from collections.abc import Awaitable, Callable

from agent_framework import (
    ChatContext,
    Message,
    ChatMiddleware,
    ChatResponse,
    Role,
    chat_middleware,
)
from agent_framework.azure import AzureAIAgentClient
from azure.identity.aio import AzureCliCredential

print("✅ All imports loaded")
# Out:
# ✅ All imports loaded

# %% [markdown]
# ## Define FSI Tool Function

# %%
def get_account_balance(account_id: str) -> str:
    """Get account balance for a customer."""
    return f"Account {account_id} has a balance of $15,432.50"

print("✅ Tool defined: get_account_balance")
# Out:
# ✅ Tool defined: get_account_balance

# %% [markdown]
# ## Define Chat Middleware
#
# Chat middleware intercepts requests before they reach the AI service.

# %%
# Class-based middleware for message observation
class InputObserverMiddleware(ChatMiddleware):
    """Observes and logs input messages."""

    async def process(
        self,
        context: ChatContext,
        call_next: Callable[[], Awaitable[None]],
    ) -> None:
        print("[Observer] Observing input messages:")
        for i, message in enumerate(context.messages):
            content = message.text if message.text else str(message.contents)
            print(f"  Message {i + 1} ({message.role}): {content[:50]}...")
        
        await call_next()
        print("[Observer] Processing completed")


# Function-based middleware for security filtering
@chat_middleware
async def security_middleware(
    context: ChatContext,
    call_next: Callable[[], Awaitable[None]],
) -> None:
    """Blocks sensitive information requests."""
    blocked_terms = ["password", "secret", "ssn", "social security"]

    for message in context.messages:
        if message.text:
            for term in blocked_terms:
                if term in message.text.lower():
                    print(f"[Security] BLOCKED: Found '{term}'")
                    context.result = ChatResponse(
                        messages=[Message(role="assistant", text="I cannot process requests for sensitive information.")]
                    )
                    return

    await call_next()

print("✅ Middleware defined: InputObserverMiddleware, security_middleware")
# Out:
# ✅ Middleware defined: InputObserverMiddleware, security_middleware

# %% [markdown]
# ## Example 1: Class-based Chat Middleware

# %%
async def class_based_example():
    print("=== Class-based Chat Middleware ===")
    
    async with (
        AzureCliCredential() as credential,
        AzureAIAgentClient(credential=credential, project_endpoint=PROJECT_ENDPOINT).as_agent(
            name="ObserverAgent",
            instructions="You are a helpful banking assistant.",
            middleware=[InputObserverMiddleware()],
            tools=get_account_balance,
        ) as agent,
    ):
        query = "What is the balance for account ACC-123?"
        print(f"User: {query}")
        result = await agent.run(query)
        print(f"Agent: {result.text if result.text else 'No response'}")

await class_based_example()
# Out:
# === Class-based Chat Middleware ===
# User: What is the balance for account ACC-123?
# [Observer] Observing input messages:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 18
#      15         result = await agent.run(query)
#      16         print(f"Agent: {result.text if result.text else 'No response'}")
# ---> 18 await class_based_example()
#
# Cell In[16], line 15, in class_based_example()
#      13 query = "What is the balance for account ACC-123?"
#      14 print(f"User: {query}")
# ---> 15 result = await agent.run(query)
#      16 print(f"Agent: {result.text if result.text else 'No response'}")
#
# File ~/Desktop/MSFT/VodaTraining/agentic-ai-immersion/.venv/lib/python3.11/site-packages/agent_framework/_agents.py:907, in RawAgent.run.<locals>._run_non_streaming()
#     895 async def _run_non_streaming() -> AgentResponse[Any]:
#     896     ctx = await self._prepare_run_context(
#     897         messages=messages,
#     898         session=session,
#    (...)    903         kwargs=kwargs,
#     904     )
#     905     response = cast(
#     906         ChatResponse[Any],
# --> 907         await self.client.get_response(  # type: ignore
#     908             messages=ctx["session_messages"],
#     909             stream=False,
#     910             options=ctx["chat_options"],  # type: ignore[reportArgumentType]
#     911             compaction_strategy=ctx["compaction_strategy"],
#     912             tokenizer=ctx["tokenizer"],
#     913             **ctx["filtered_kwargs"],
#     914         ),
#     915     )
#     917     if not response:
#     918         raise AgentInvalidResponseException("Chat client did not return a response.")
#
# File ~/Desktop/MSFT/VodaTraining/agentic-ai-immersion/.venv/lib/python3.11/site-packages/agent_framework/_middleware.py:1053, in ChatMiddlewareLayer.get_response.<locals>._execute()
#    1052 async def _execute() -> ChatResponse | ResponseStream[ChatResponseUpdate, ChatResponse] | None:
# -> 1053     return await pipeline.execute(
#    1054         context=context,
#    1055         final_handler=self._middleware_handler,
#    1056     )
#
# File ~/Desktop/MSFT/VodaTraining/agentic-ai-immersion/.venv/lib/python3.11/site-packages/agent_framework/_middleware.py:937, in ChatMiddlewarePipeline.execute(self, context, final_handler)
#     935 first_handler = create_next_handler(0)
#     936 with contextlib.suppress(MiddlewareTermination):
# --> 937     await first_handler()
#     939 if context.result and isinstance(context.result, ResponseStream):
#     940     for hook in context.stream_transform_hooks:
#
# File ~/Desktop/MSFT/VodaTraining/agentic-ai-immersion/.venv/lib/python3.11/site-packages/agent_framework/_middleware.py:931, in ChatMiddlewarePipeline.execute.<locals>.create_next_handler.<locals>.current_handler()
#     929 async def current_handler() -> None:
#     930     # MiddlewareTermination bubbles up to execute() to skip post-processing
# --> 931     await self._middleware[index].process(context, create_next_handler(index + 1))
#
# Cell In[15], line 13, in InputObserverMiddleware.process(self, context, call_next)
#      11 for i, message in enumerate(context.messages):
#      12     content = message.text if message.text else str(message.contents)
# ---> 13     print(f"  Message {i + 1} ({message.role.value}): {content[:50]}...")
#      15 await call_next()
#      16 print("[Observer] Processing completed")
#
# AttributeError: 'str' object has no attribute 'value'

# %% [markdown]
# ## Example 2: Function-based Security Middleware

# %%
async def security_example():
    print("=== Security Middleware ===")
    
    async with (
        AzureCliCredential() as credential,
        AzureAIAgentClient(credential=credential).as_agent(
            name="SecureAgent",
            instructions="You are a helpful assistant.",
            middleware=[security_middleware],
        ) as agent,
    ):
        # Normal query
        print("\n--- Normal Query ---")
        query = "Hello, how are you?"
        print(f"User: {query}")
        result = await agent.run(query)
        print(f"Agent: {result.text if result.text else 'No response'}")

        # Blocked query
        print("\n--- Blocked Query ---")
        query = "What is my password?"
        print(f"User: {query}")
        result = await agent.run(query)
        print(f"Agent: {result.text if result.text else 'No response'}")

await security_example()

# %% [markdown]
# ## Example 3: Run-level Middleware

# %%
async def run_level_example():
    print("=== Run-level Middleware ===")
    
    async with (
        AzureCliCredential() as credential,
        AzureAIAgentClient(credential=credential).as_agent(
            name="FlexibleAgent",
            instructions="You are a helpful assistant.",
            # No middleware at agent level
        ) as agent,
    ):
        # Run without middleware
        print("\n--- Without Middleware ---")
        query = "Hello"
        print(f"User: {query}")
        result = await agent.run(query)
        print(f"Agent: {result.text if result.text else 'No response'}")

        # Run with middleware for this call only
        print("\n--- With Run-level Middleware ---")
        query = "What is my SSN?"
        print(f"User: {query}")
        result = await agent.run(query, middleware=[security_middleware])
        print(f"Agent: {result.text if result.text else 'No response'}")

await run_level_example()

# %% [markdown]
# ## 📋 Key Takeaways
#
# | Feature | Description |
# |---------|-------------|
# | **ChatMiddleware class** | Class-based middleware with `process()` method |
# | **@chat_middleware** | Function decorator for chat middleware |
# | **Agent-level** | Middleware applies to all runs |
# | **Run-level** | Middleware applies to specific run only |
# | **context.terminate** | Stop execution and return override response |
